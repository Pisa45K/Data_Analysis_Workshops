# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
bills = df['total_bill']
tips = df['tip']
sex= df['sex']
plt.scatter(bills, tips)
plt.xlabel('Total Bill')
plt.ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
sns.scatterplot(x='total_bill', y='tip', hue='time', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
ss.pearsonr(df['total_bill'], df['tip'])
# Out:
# PearsonRResult(statistic=np.float64(0.6757341092113647), pvalue=np.float64(6.692470646863343e-34))

# %%
sns.boxplot(data=df, y='total_bill', x='size')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
ss.kendalltau(df['total_bill'], df['tip'])
# Out:
# SignificanceResult(statistic=np.float64(0.517180972142381), pvalue=np.float64(2.445572848021409e-32))

# %%
#Heatmap of correlation
corr = df.corr(numeric_only=True , method = 'kendall')

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')

plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

#use this methods in aribnb
